# %% [markdown]
# top 5 companies
# old data
# 5000
# 3000

# %%
import pandas as pd
from web_email_scrapper_multiEngine import get_email_from_snippet, fetch_yahoo_results, fetch_bing_results
import time
from datetime import datetime, timedelta
import math
import random ,get_email_flags

# %%
file = r'/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/created_emails/EW-ND-10Mar-output.csv'

# %%
cc =  pd.read_csv(file)
cc
# Out:
#       Unnamed: 0  Srl No                Company                 Contact Name  \
# 0              0       2  1 accord technologies               David Thompson
# 1              1       3       1 acord services                 Kelvin Nolen
# 2              2       6            1 exam prep                    Ori Gross
# 3              3       8       1 point networks              James Daugherty
# 4              5      12  1 sun solar companies              Rita Sosa-Bravo
# ...          ...     ...                    ...                          ...
# 8934       52284  198949                 sagint                  Erich Fritz
# 8935       52285  198951                   sago                      Ann Ali
# 8936       52286  198952                   sago               Jennifer Pratt
# 8937       52287  198953            sah systems               John Schaeffer
# 8938       52288  198954   sahal tech solutions  Diriye Ahmed Jambiir Sultan
#
#      First Name   Last Name  \
# ...

# %%
cc = get_email_flags.get_flags(cc,'email')
cc = cc[cc['match'] != 'Low']
cc.to_csv(file,index = False)
# Out:
# Index(['unnamed: 0', 'srl no', 'company', 'contact name', 'first name',
#        'last name', 'designation', 'location', 'industry', 'mailer_status',
#        'email'],
#       dtype='object')

# %%
import pickle

f1 = r"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/main_database/email_patterns.pkl"
f2 = r'/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/main_database/email_patterns.pkl copy 2'
# Read the pickle file
with open( f2, "rb") as file:
    data_dict = pickle.load(file)  # Load as a dictionary

# Print or use the dictionary
print(len(data_dict))
# Out:
# 11446

# %%
with open(f2, "rb") as file:
    data = pickle.load(file)  # Load the dictionary

# Convert dictionary to DataFrame
df = pd.DataFrame(list(data.items()), columns=["Key", "Value"])

# Save to CSV
df.to_csv("csv_filedd.csv", index=False)

# %%
d = '1 health source inc.'
print((data_dict[))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 d = '1 health source inc.'
# ----> 2 print((data_dict[0]))
#
# KeyError: 0

# %%
# New dictionary to replace existing content
new_data = {'10th sfg': 'LastName@soc.mil'}

# Replace content by overwriting the file
with open("/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/main_database/email_patterns.pkl", "wb") as file:
    pickle.dump(new_data, file)

# %%
import pickle

# Read the pickle file
with open("/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/main_database/email_patterns.pkl", "rb") as file:
    data_dict = pickle.load(file)  # Load as a dictionary

# Print or use the dictionary
print(len(data_dict))
# Out:
# 10965

# %%
output_path = r'/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/unique_companies.csv'
missing_data = pd.read_csv(output_path)
missing_data
# Out:
#                                      Company
# 0             global auto processing service
# 1      global automotive processing services
# 2                  global aviation resources
# 3                        global bin builders
# 4                           global borescope
# ...                                      ...
# 33797                 zwilling j.a. henckels
# 33798                                   zyde
# 33799                               zylabyte
# 33800                                   zync
# 33801                                  zynga
#
# [33802 rows x 1 columns]
