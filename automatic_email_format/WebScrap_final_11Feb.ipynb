# %% [markdown]
# top 5 companies
# old data
# 5000
# 3000

# %%
import pandas as pd
from web_email_scrapper_multiEngine import get_email_from_snippet, fetch_yahoo_results, fetch_bing_results
import time
from datetime import datetime, timedelta
import math
import random

# %%
import pandas as pd
import os
import re
excel_data = pd.ExcelFile(r'/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/automatic_email_format/tool-test-data-10Feb.xlsx')
sheets = excel_data.sheet_names[:5]  # Get the first 5 sheets
data = pd.concat([excel_data.parse(sheet) for sheet in sheets], ignore_index=True) 
data['Company'][0]
# Out:
# '060 technology solutions'

# %%
data.shape[0]
# Out:
# 2369

# %%
# # Specify the file name
# file_name = r"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/database_output_files/companies_list.txt"
# # Read the text file into a list
# with open(file_name, "r") as file:
#     lines = file.readlines()

# %%
# # Remove newline characters from each line
# lines = [line.strip() for line in lines]
# lines = lines[50:66]
# print (len(lines))

# %%
queries = []
for i in data['Company']:
  
    queries.append(f"email format for {i}")
print (len(queries))
# Out:
# 2369

# %%
# batch_size = 75
# num_batches = math.ceil(len(queries) / batch_size)
# all_results = []

# start_time = time.time()  # Start time for entire execution
# print ("Number of batch:", num_batches, " and each batch have ", batch_size, " many rows ")

# all_results = []

# for batch_idx in range(num_batches):
#     # Start time for this batch
#     batch_start_time = time.time()

#     # Get queries for the current batch
#     start_idx = batch_idx * batch_size
#     end_idx = start_idx + batch_size
#     current_queries = queries[start_idx:end_idx]
    
#     print(f"\nFetching batch {batch_idx + 1}...")
#     for query in current_queries:
#         try:

#             results = fetch_yahoo_results(query, 10)
#             all_results.append({'query': query, 'engine': "Retry", 'results': results})
#             print ("------------------")
#             print (results)
#             print ("------------------")
#             all_results.append({'query': query, 'results': results})
#         except Exception as e:
#             print(f"Failed to fetch results for query '{query}': {e}")
#             # In case of error, we append the result with "NA" values for this query
#             all_results.append({'query': query, 'engine': "Retry", 'results': [{'title': 'error', 'link': 'error', 'snippet': 'error'}]})

#     # End time for this batch
#     batch_end_time = time.time()
#     batch_duration = batch_end_time - batch_start_time
#     print(f"Batch {batch_idx + 1} completed in {batch_duration:.2f} seconds.")
    
#     # Delay of 1 minute after each batch
#     print("Waiting for 1 minute before starting the next batch...")
#     time.sleep(1)  # Wait for 60 seconds (1 minute)
#     break

# # End time for entire execution
# end_time = time.time()
# total_duration = end_time - start_time
# print(f"\nTotal execution time: {total_duration:.2f} seconds.")

# %%
search_engines = [fetch_yahoo_results, fetch_bing_results]  # Alternating search engines\
h = ['Yahoo', 'Bing']
engine_pt = 0
batch_size = 73
num_batches = math.ceil(len(queries) / batch_size)
all_results = []

yahoo_downtime = datetime.now() - timedelta(hours=1)
bing_downtime = datetime.now() - timedelta(hours=1)
d= datetime.now()

down_duration = timedelta(hours=1)  # Yahoo stays down for 1 hour

start_time = time.time()  # Start time for entire execution
print ("Number of batch:", num_batches, " and each batch have ", batch_size, " many rows ")

for batch_idx in range(num_batches):
    print ("Batch--------------------------------------", batch_idx)
    # Start time for this batch
    batch_start_time = time.time()
    # Get queries for the current batch
    start_idx = batch_idx * batch_size
    end_idx = start_idx + batch_size
    current_queries = queries[start_idx:end_idx]
    print ("Index-------->", start_idx,"::",end_idx)

    for query in current_queries:
        random_number = random.randint(1, 5)
        print(random_number)
        try:
            if engine_pt == 0:
                if datetime.now() >= yahoo_downtime + down_duration:
                    try :
                        results = search_engines[engine_pt](query, num_results=10)
                    except:
                        yahoo_downtime = datetime.now()
                    if not results:  # If results are empty, append a result with "NA"
                        results.append({'title': 'NA', 'link': 'NA', 'snippet': 'NA'})
                    all_results.append({'query': query, 'engine': h[engine_pt], 'results': results})
                else:
                    try :
                        results = search_engines[1-engine_pt](query, num_results=10)
                    except:
                        yahoo_downtime = datetime.now()
                    if not results:  # If results are empty, append a result with "NA"
                        results.append({'title': 'NA', 'link': 'NA', 'snippet': 'NA'})
                    all_results.append({'query': query, 'engine': h[1-engine_pt], 'results': results})
            if engine_pt == 1:
                if datetime.now() >= bing_downtime + down_duration:
                    try :
                        results = search_engines[engine_pt](query, num_results=10)
                    except:
                        bing_downtime = datetime.now()
                    if not results:  # If results are empty, append a result with "NA"
                        results.append({'title': 'NA', 'link': 'NA', 'snippet': 'NA'})
                    all_results.append({'query': query, 'engine': h[engine_pt], 'results': results})
                else:
                    try :
                        results = search_engines[1-engine_pt](query, num_results=10)
                    except:
                        bing_downtime = datetime.now()
                    if not results:  # If results are empty, append a result with "NA"
                        results.append({'title': 'NA', 'link': 'NA', 'snippet': 'NA'})
                    all_results.append({'query': query, 'engine': h[1-engine_pt], 'results': results})

        except Exception as e:
            print(f"                Failed to fetch results for query '{query}': {e}")  
        time.sleep(random_number)
    engine_pt = 1- engine_pt  
    time.sleep(60)
# Out:
# Number of batch: 33  and each batch have  73  many rows
# Batch-------------------------------------- 0
# Index--------> 0 :: 73
# 3
# 3
# 1
# 2
# 4
# 2
# 3
# 3
# 3
# 3
# 2
# 5
# 3
# 5
# 4
# 3
# 4
# 2
# 3
# 4
# 4
# 4
# 3
# 2
# 3
# 5
# 5
# 3
# 1
# 4
# 3
# 1
# 1
# 1
# 1
# 5
# 1
# 2
# 1
# 4
# 5
# 2
# 2
# 2
# 1
# 2
# 4
# 4
# 1
# 2
# 1
# 5
# 5
# 5
# 3
# 4
# 2
# 4
# 5
# 5
# 5
# 3
# 3
# 3
# 1
# 1
# 2
# 2
# 2
# 3
# 3
# 3
# 1
# Batch-------------------------------------- 1
# Index--------> 73 :: 146
# 5
# 5
# 4
# 2
# 4
# 1
# 3
# 2
# 2
# 3
# 3
# 2
# 4
# 3
# 3
# 2
# 2
# 2
# 1
# 1
# 4
# 3
# 3
# 1
# 2
# 1
# 5
# 1
# 4
# 5
# 5
# 1
# 1
# 2
# 5
# 3
# 1
# 5
# 3
# 1
# 5
# 1
# 3
# 3
# 2
# 3
# 1
# 4
# 4
# 1
# 5
# 3
# 1
# 3
# 3
# 2
# 2
# 4
# 5
# 1
# 2
# 2
# 1
# 3
# 1
# 3
# 4
# 2
# 1
# 1
# 1
# 5
# 4
# Batch-------------------------------------- 2
# Index--------> 146 :: 219
# 2
# 5
# 5
# 5
# 3
# 4
# 4
# 5
# 3
# 2
# 4
# 5
# 4
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 3
# 3
# 1
# 2
# 2
# 5
# 3
# 5
# 4
# 3
# 5
# 5
# ...

# %%
# Out:
# datetime.datetime(2025, 2, 11, 0, 13, 34, 841890)

# %%
# Out:
# False
