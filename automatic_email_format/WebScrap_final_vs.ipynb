# %% [markdown]
# top 5 companies
# old data
# 5000
# 3000

# %%
from web_email_scrapper import batch_scrapper, batch_scrapper2, batch_scrapper_3 ,get_clean_data, get_csv_formatted,get_company_email_format
import pandas as pd
from web_email_scrapper_multiEngine import distribute_queries_across_engines, fetch_bing_results, fetch_startpage_results, fetch_yahoo_results

# %%
''' 
# here i will define the loop for fetching data from different engines
'''
# Out:
# ' \n# here i will define the loop for fetching data from different engines\n'

# %%
# Specify the file name
file_name = r"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/database_output_files/companies_list.txt"
# Read the text file into a list
with open(file_name, "r") as file:
    lines = file.readlines()
    print (lines)
# Remove newline characters from each line
# Out:
# ['10th sfg\n', '10th sfga\n', '10th special forces group\n', '24 hour fitness\n', '24-7 intouch\n', '314e corporation\n', '360 healthcare staffing\n', '3gimbals\n', '4 rivers equipment\n', '4th infantry division\n', '4th judicial district\n', '4th judicial district attorney\n', '4th judicial district attorneys office\n', '4th judicial district court\n', '5280 publishing\n', '561st network operations squadron\n', '75th innovation command\n', '7-eleven\n', '8z mortgage\n', '8z real estate\n', 'a time\n', 'a time!\n', 'a world of tile\n', 'aaa\n', 'aaa - the auto club group\n', 'aaa colorado\n', 'aaa insurance\n', 'aafes main exchange\n', 'aapc\n', 'aar\n', 'abacus\n', 'abacus solutions group\n', 'abacus technology corporation\n', 'abba eye care\n', 'abba technologies\n', 'abbvie\n', 'abc\n', 'abc child development center\n', 'abc supply co\n', 'abf freight\n', 'above and beyond home care\n', 'academy bank\n', 'academy district\n', 'academy for advanced and creative learning\n', 'academy of nutrition and dietetics\n', 'academy school district\n', 'accedian\n', 'accelirate\n', 'accenture\n', 'accenture enkitec group\n', 'access data consulting corp\n', 'access products\n', 'leidos\n', 'accountemps\n', 'accounting\n', 'accredited home lenders\n', 'accretive health\n', 'accuoss\n', 'ace hardware\n', 'ace hardware corporation\n', 'acell\n', 'aces\n', 'aci learning center\n', 'aclu of colorado\n', 'acn\n', 'leidos cyber\n', 'acorn petroleum\n', 'leiters\n', 'acs\n', 'acsi\n', 'action coach business coaching\n', 'actiontec electronics\n', 'lend lease\n', 'active release techniques\n', 'activehealth management\n', 'lendlease\n', 'acuity eyecare group\n', 'acuity insurance\n', 'acv auctions\n', 'lenscrafters\n', 'ad hoc\n', 'adamo homes\n', 'adams 12 five star schools\n', 'lesea broadcasting\n', 'adams communication & engineering technology\n', 'adaptive solutions group\n', 'le-vel\n', 'add staff\n', 'level 3 communications\n', 'levi strauss & co\n', 'adecco group\n', 'lewan & associates\n', 'lewan technology\n', 'adesa\n', 'lewis roca rothgerber christie\n', 'adinstruments\n', 'lewis-palmer school district 38\n', 'admiral security services\n', 'lexis nexis\n', 'adp\n', 'lexisnexis\n', 'adpro 360\n', 'ads\n', 'ads on magnets\n', 'adt\n', 'advance auto parts\n', 'advance services\n', 'lexisnexis legal\n', 'advanced concepts and technologies international\n', 'advanced health care of las vegas\n', 'advanced network management\n', 'advanced technology services\n', 'advantage logistics\n', 'advantage sales & marketing\n', 'lg electronics\n', 'advantage services\n', 'advantage solutions: sales marketing technology\n', 'liberty av solutions\n', 'advantis global services\n', 'liberty high school\n', 'advent global solutions\n', 'adventure treks\n', 'adventures in missions\n', 'liberty mutual insurance\n', 'advisors asset management\n', 'advocare\n', 'advocate aurora health\n', 'ae associates\n', 'liberty tax\n', 'aecom\n', 'life care centers of america\n', 'life time\n', 'life time - healthy way of life\n', 'life time fitness\n', 'life vantage\n', 'lifechurch\n', 'lifesave transport\n', 'lifetime fitness\n', 'lifetouch national school studios\n', 'lifevantage\n', 'lifevantage corporation\n', 'lightning bolt\n', 'limu\n', 'linc energy\n', 'lincare holdings\n', 'lincoln tech\n', 'linden resources\n', 'lindsay precast\n', 'linear manufacturing\n', 'linquest\n', 'aecom/urs/eg&g\n', 'lionbridge\n', 'aegis\n', 'aegis technologies\n', 'listenup\n', 'aei\n', 'lithia motors\n', 'aermor\n', 'aerocare holdings\n', 'little caesars pizza\n', 'aerodyne\n', 'aerodyne industries\n', 'little sunshines playhouse\n', 'aeroflow healthcare\n', 'aeropostale\n', 'livanova\n', 'aerotech\n', 'aerotek\n', 'live nation\n', 'liveclicker\n', 'living on the edge\n', 'living the dream\n', 'livongo\n', 'ljt & associates\n', 'aesbus company\n', 'aetna\n', 'loandepot\n', 'aetna a cvs health company\n', 'loch harbour group\n', 'loci controls\n', 'affinity integrated solutions\n' ...

# %%
# Remove newline characters from each line
lines = [line.strip() for line in lines]
lines = lines[50:66]
print (len(lines))
# Out:
# 16

# %%
queries = []
for i in lines:
  
    queries.append(f"email format for {i}")

# %%
# Example usage
if __name__ == "__main__":
    batch_size = 2 # Number of queries per batch
    
    # Distribute queries across engines
    results = distribute_queries_across_engines(queries, batch_size)
    
    # Display results
    for result in results:
        print(f"\nQuery: {result['query']} (Engine: {result['engine']})\n")
        for i, item in enumerate(result['results'], 1):
            print(f"{i}. {item['title']}")
            print(f"   Link: {item['link']}")
            print(f"   Snippet: {item.get('snippet', 'No snippet available')}\n")
# Out:
# Number of batch: 1  and each batch have  2  many rows
#
# Fetching batch 1...
# Batch 1 completed in 1.83 seconds.
# Waiting for 1 minute before starting the next batch...
#
# Total execution time: 4.83 seconds.
#
# Query: email format for access data consulting corp (Engine: Retry)
#
# 1. Access Data Consulting Corporation Email Format
#    Link: https://rocketreach.co/access-data-consulting-corporation-email-format_b5c7029ff42e0d30
#    Snippet: Access Data Consulting Corporation uses 4 email formats: 1. first_initial last@adcc.com (85.7%). Enter a name to find & verify an email >>>
#
# 2. Access Data Consulting Corporation Information - RocketReach
#    Link: https://rocketreach.co/access-data-consulting-corporation-profile_b5c7029ff42e0d30
#    Snippet: Access Data Consulting Corporation is an IT Services and IT Consulting, Custom Software & Technical Consulting, and Staff Augumentation company located in ...
#
# 3. Access Data Consulting Corporation
#    Link: https://www.adcc.com/
#    Snippet: Access Data Consulting Corporation provides a diversified staff of information technology professionals to design, develop, maintain and support IT systems ...
#
# 4. Get In Touch :: Access Data Consulting Corporation
#    Link: https://www.adcc.com/services/get-in-touch
#    Snippet: Ready to Partner with Us? ; First Name*. Last Name* ; Company*. Location (City and State)* ; Email Address*. Phone Number* ...
#
# 5. Access Data Consulting Corp Jobs & Careers | Dice.com
#    Link: https://www.dice.com/company-profile/6aff860f-e565-5f7b-b592-7687929957ec
#    Snippet: View jobs for Access Data Consulting Corp and discover how they match to what's important to you, including remote-work policies, benefits, technology, ...
#
#
# Query: email format for access products (Engine: Retry)
#
# 1. How to write a mail for an access request to a manager - Quora
#    Link: https://www.quora.com/How-do-I-write-a-mail-for-an-access-request-to-a-manager
#    Snippet: 10 Mar 2022 ... Greet Them. Write your purpose for the email in the subject line. Explain about what access you require. Add purpose of taking that access in ...
#
# 2. 13 Essential Product Launch Email Templates & Examples
#    Link: https://www.maestrolabs.com/email-templates/13-essential-product-launch-email-templates-examples
#    Snippet: 12 Feb 2024 ... This collection includes diverse scenarios and formats to help you craft professional emails tailored to your specific needs. From announcing ...
#
# 3. 20+ Professional Business Email Examples & Templates
#    Link: https://www.sender.net/blog/business-email/
#    Snippet: 21 Aug 2024 ... Business emails follow a structured format, usually including a subject line, a polite greeting, the body of the email, and closing with a ...
#
# 4. The Access Group Email Format - LeadIQ
#    Link: https://leadiq.com/c/the-access-group/5a1d965e2300005b0085063b/email-format
#    Snippet: The Access Group's email format typically follows the pattern of First.Last@theaccessgroup.com; this email format is used 95% of the time. Other contacts within ...
#
# 5. Access Email Format | accessefm.com Emails - RocketReach
#    Link: https://rocketreach.co/access-email-format_b5c28b75f42e0ed3
#    Snippet: The most common Access email format is [first].[last] (ex. jane.doe@accessefm.com), which is being used by 81.8% of Access work email addresses.

# %%
import json

# Save dictionary to a text file in JSON format
with open("data.txt", "w") as file:
    json.dump(results, file)

# %%
results
# Out:
# [{'query': 'email format for access data consulting corp',
#   'engine': 'Retry',
#   'results': [{'title': 'Access Data Consulting Corporation Email Format',
#     'link': 'https://rocketreach.co/access-data-consulting-corporation-email-format_b5c7029ff42e0d30',
#     'snippet': 'Access Data Consulting Corporation uses 4 email formats: 1. first_initial last@adcc.com (85.7%). Enter a name to find & verify an email >>>'},
#    {'title': 'Access Data Consulting Corporation Information - RocketReach',
#     'link': 'https://rocketreach.co/access-data-consulting-corporation-profile_b5c7029ff42e0d30',
#     'snippet': 'Access Data Consulting Corporation is an IT Services and IT Consulting, Custom Software & Technical Consulting, and Staff Augumentation company located in\xa0...'},
#    {'title': 'Access Data Consulting Corporation',
#     'link': 'https://www.adcc.com/',
#     'snippet': 'Access Data Consulting Corporation provides a diversified staff of information technology professionals to design, develop, maintain and support IT systems\xa0...'},
#    {'title': 'Get In Touch :: Access Data Consulting Corporation',
#     'link': 'https://www.adcc.com/services/get-in-touch',
#     'snippet': 'Ready to Partner with Us? ; First Name*. Last Name* ; Company*. Location (City and State)* ; Email Address*. Phone Number*\xa0...'},
#    {'title': 'Access Data Consulting Corp Jobs & Careers | Dice.com',
#     'link': 'https://www.dice.com/company-profile/6aff860f-e565-5f7b-b592-7687929957ec',
#     'snippet': "View jobs for Access Data Consulting Corp and discover how they match to what's important to you, including remote-work policies, benefits, technology,\xa0..."}]},
#  {'query': 'email format for access products',
#   'engine': 'Retry',
#   'results': [{'title': 'How to write a mail for an access request to a manager - Quora',
#     'link': 'https://www.quora.com/How-do-I-write-a-mail-for-an-access-request-to-a-manager',
#     'snippet': '10 Mar 2022 ... Greet Them. Write your purpose for the email in the subject line. Explain about what access you require. Add purpose of taking that access in\xa0...'},
#    {'title': '13 Essential Product Launch Email Templates & Examples',
#     'link': 'https://www.maestrolabs.com/email-templates/13-essential-product-launch-email-templates-examples',
#     'snippet': '12 Feb 2024 ... This collection includes diverse scenarios and formats to help you craft professional emails tailored to your specific needs. From announcing\xa0...'},
#    {'title': '20+ Professional Business Email Examples & Templates',
#     'link': 'https://www.sender.net/blog/business-email/',
#     'snippet': '21 Aug 2024 ... Business emails follow a structured format, usually including a subject line, a polite greeting, the body of the email, and closing with a\xa0...'},
#    {'title': 'The Access Group Email Format - LeadIQ',
#     'link': 'https://leadiq.com/c/the-access-group/5a1d965e2300005b0085063b/email-format',
#     'snippet': "The Access Group's email format typically follows the pattern of First.Last@theaccessgroup.com; this email format is used 95% of the time. Other contacts within\xa0..."},
#    {'title': 'Access Email Format | accessefm.com Emails - RocketReach',
#     'link': 'https://rocketreach.co/access-email-format_b5c28b75f42e0ed3',
#     'snippet': 'The most common Access email format is [first].[last] (ex. jane.doe@accessefm.com), which is being used by 81.8% of Access work email addresses.'}]}]

# %%
import pandas as pd
import re
from urllib.parse import urlparse

# Input dictionary
data = results

# Function to extract domain name from URL
def extract_website(url):
    domain = urlparse(url).netloc
    return domain.split('.')[0] if domain else "Unknown"

# Function to extract email format from snippet
def extract_email(snippet):
    match = re.search(r'[\w\.\[\]]+@[\w\.\[\]]+', snippet)  # Extracts email-like patterns
    return match.group(0) if match else "Not Found"

# Function to extract accuracy from snippet (if mentioned)
def extract_accuracy(snippet):
    match = re.search(r'(\d{1,3}\.\d+)%', snippet)
    return float(match.group(1)) if match else "Unknown"

# Creating DataFrame
records = []
for entry in data:
    for result in entry['results']:
        text = (entry['query'])
        # Extract text after "email format for"
        company = text.replace("email format for", "").strip()
        website = extract_website(result['link'])
        email = extract_email(result['snippet'])
        accuracy = extract_accuracy(result['snippet'])
        query = company
        records.append({"Company":query,"Website": website, "Email": email, "Accuracy": accuracy})

df = pd.DataFrame(records)

# Display DataFrame
print(df)
# Out:
#                        Company      Website                          Email  \
# 0  access data consulting corp  rocketreach                  last@adcc.com
# 1  access data consulting corp  rocketreach                      Not Found
# 2  access data consulting corp          www                      Not Found
# 3  access data consulting corp          www                      Not Found
# 4  access data consulting corp          www                      Not Found
# 5              access products          www                      Not Found
# 6              access products          www                      Not Found
# 7              access products          www                      Not Found
# 8              access products       leadiq  First.Last@theaccessgroup.com
# 9              access products  rocketreach         jane.doe@accessefm.com
#
#   Accuracy
# 0     85.7
# 1  Unknown
# 2  Unknown
# 3  Unknown
# 4  Unknown
# 5  Unknown
# 6  Unknown
# 7  Unknown
# 8  Unknown
# 9     81.8

# %%
# Convert the list of dictionaries to a DataFrame
df = df

# Print the DataFrame
df.to_csv("multiengine.csv")

# %%
import requests
import random
import time
from bs4 import BeautifulSoup

def fetch_bing_results(query, num_results=5):
    language = 'en'
    url = f"https://www.bing.com/search?q={query}&setlang={language}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    results = []
    for item in soup.find_all('li', class_='b_algo')[:num_results]:
        title = item.find('h2')
        link = title.find('a')['href'] if title else None
        snippet = item.find('p').text if item.find('p') else None
        if title and link:
            results.append({'title': title.text, 'link': link, 'snippet': snippet})
    if not results:
        results.append({'title': 'NA', 'link': 'NA', 'snippet': 'NA'})
    return results

def fetch_yahoo_results(query, num_results=5):
    url = f"https://search.yahoo.com/search?p={query}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    results = []
    for item in soup.find_all('div', class_='Sr')[:num_results]:
        title = item.find('h3')
        link = item.find('a')['href'] if item.find('a') else None
        snippet = item.find('p').text if item.find('p') else None
        if title and link:
            results.append({'title': title.text, 'link': link, 'snippet': snippet})
    if not results:
        results.append({'title': 'NA', 'link': 'NA', 'snippet': 'NA'})
    return results

def scrape_companies(companies, batch_size=90):
    total_companies = len(companies)
    results = []

    for i in range(0, total_companies, batch_size):
        batch = companies[i:i + batch_size]
        engine = fetch_yahoo_results if (i // batch_size) % 2 == 0 else fetch_bing_results
        
        for company in batch:
            print(f"Scraping {company} using {'Yahoo' if engine == fetch_yahoo_results else 'Bing'}...")
            result = engine(company)
            results.append({"company": company, "results": result})
            
            sleep_time = random.randint(1, 5)
            print(f"Sleeping for {sleep_time} seconds...")
            time.sleep(sleep_time)
    
    return results

# Example usage:
companies_list = [f"Company {i}" for i in range(1, 1001)]  # Simulating 1000 companies

# %%
queries
# Out:
# ['email format for access data consulting corp',
#  'email format for access products']

# %%
import math
batch_size = 4 
num_batches = math.ceil(len(queries) / batch_size)
all_results = []

start_time = time.time()  # Start time for entire execution
print ("Number of batch:", num_batches, " and each batch have ", batch_size, " many rows ")

all_results = []

for batch_idx in range(num_batches):
    # Start time for this batch
    batch_start_time = time.time()

    # Get queries for the current batch
    start_idx = batch_idx * batch_size
    end_idx = start_idx + batch_size
    current_queries = queries[start_idx:end_idx]
    
    print(f"\nFetching batch {batch_idx + 1}...")
    for query in current_queries:
        try:

            results = fetch_yahoo_results(query, 10)
            all_results.append({'query': query, 'engine': "Retry", 'results': results})
            print ("------------------")
            print (results)
            print ("------------------")
            all_results.append({'query': query, 'results': results})
        except Exception as e:
            print(f"Failed to fetch results for query '{query}': {e}")
            # In case of error, we append the result with "NA" values for this query
            all_results.append({'query': query, 'engine': "Retry", 'results': [{'title': 'error', 'link': 'error', 'snippet': 'error'}]})

    # End time for this batch
    batch_end_time = time.time()
    batch_duration = batch_end_time - batch_start_time
    print(f"Batch {batch_idx + 1} completed in {batch_duration:.2f} seconds.")
    
    # Delay of 1 minute after each batch
    print("Waiting for 1 minute before starting the next batch...")
    time.sleep(1)  # Wait for 60 seconds (1 minute)
    break

# End time for entire execution
end_time = time.time()
total_duration = end_time - start_time
print(f"\nTotal execution time: {total_duration:.2f} seconds.")
# Out:
# Number of batch: 4  and each batch have  4  many rows
#
# Fetching batch 1...
# ------------------
# [{'title': 'www.neverbounce.com · company · access-dataAccess Data Consulting Email verification & Email checker ...', 'link': 'https://www.neverbounce.com/company/access-data-consulting/693452', 'snippet': " The most accurate and popular Access Data Consulting's email format is first [1 letter] + last (ex. JSmith@adcc.com). Access Data Consulting also uses first (ex. John@adcc.com) and first.last (ex. John.Smith@adcc.com) as email structures. "}, {'title': 'contactout.com · company · access-data-consultingAccess Data Consulting Corporation Email Format & Employee ...', 'link': 'https://contactout.com/company/access-data-consulting-corporation-5997553', 'snippet': ' Get details for Access Data Consulting Corporation’s 30 employees, email format for adcc.com and phone numbers. At Access Data Consulting Corporation, we team with clients to help them obtain the absolute best resources for their needs. '}, {'title': 'leadiq.com · 5a1d90305400005c0075ce06 · email-formatAccess | Information Management Email Format - leadiq.com', 'link': 'https://leadiq.com/c/access--information-management/5a1d90305400005c0075ce06/email-format', 'snippet': " Find Access | Information Management's most common email address formats to build your pipeline with confidence. Get accurate & updated contact data with LeadIQ. Book a demo today. "}, {'title': 'www.zoominfo.com · c · access-data-consulting-corpAccess Data Consulting - Overview, News & Similar ... - ZoomInfo', 'link': 'https://www.zoominfo.com/c/access-data-consulting-corp/693452', 'snippet': 'Apr 28, 2020 ·   View Email Formats for Access Data Consulting. Access Data Consulting financials insights. Gather financial insights about Access Data Consulting, including details on funding rounds, investors, total funding, and acquisitions, to gain a comprehensive understanding of their financial strategy. '}, {'title': 'www.lusha.com · business · 5f5367910269e7afAccess data consulting corporation - Email Address & Phone ...', 'link': 'https://www.lusha.com/business/5f5367910269e7af/', 'snippet': ' Reach decision-makers at Access Data Consulting Corporation. Find their phone numbers & email addresses. It’s free. - Lusha '}, {'title': 'rocketreach.co · access-data-consultingAccess Data Consulting Corporation Management', 'link': 'https://rocketreach.co/access-data-consulting-corporation-management_b5c7029ff42e0d30', 'snippet': " Looking for a particular Access Data Consulting Corporation employee's phone or email? "}]
# ------------------
# ------------------
# [{'title': 'www.rexandthebeast.com · access-request-email-sampleAccess Request Email Sample: How to Request Access to Files ...', 'link': 'https://www.rexandthebeast.com/access-request-email-sample/', 'snippet': 'Feb 1, 2025 ·  Access Request Email Template Structure. When requesting access to sensitive information or systems, a well-structured email is essential. Here’s a step-by-step guide to crafting an effective access request email: 1. Subject Line '}, {'title': 'getmage.io · sample-email-for-access-requestEffective Guidelines: Crafting A Sample Email For Access ...', 'link': 'https://getmage.io/sample-email-for-access-request/', 'snippet': 'Jan 10, 2025 ·   Learn how to write an effective sample email for an access request. This article provides guidelines and tips for composing a professional and concise email to obtain access to resources, information, or systems. '}, {'title': 'getmage.io · request-access-emailHow to Write an Effective Request Access Email for Smooth ...', 'link': 'https://getmage.io/request-access-email/', 'snippet': 'Jan 19, 2025 ·   Let’s break down the best way to put your request into an email that’s clear, professional, and likely to get you the access you need. Here’s a simple structure that you can follow: Subject Line: This is your first impression. Keep it clear and concise. Salutation: Always start with a friendly greeting. '}, {'title': 'www.matbud.edu.pl · sample-email-for-access-requestSample Email for Access Request: Tips and Examples for ...', 'link': 'https://www.matbud.edu.pl/sample-email-for-access-request/', 'snippet': 'Apr 21, 2024 ·   To help you out, we’ve put together some sample emails for access requests that you can use as a starting point. These examples cover a range of scenarios, from requesting access to a new software system to asking for permission to view certain documents or files. '}, {'title': 'www.rexandthebeast.com · how-to-send-accessHow To Send An Effective Access Request Email - Rexandthebeast', 'link': 'https://www.rexandthebeast.com/how-to-send-access-request-email/', 'snippet': 'Jan 14, 2025 ·   Learn how to craft an effective access request email to gain permission to confidential information or resources. We provide a step-by-step guide, tips, and examples to help you get the access you need. '}, {'title': 'getmage.io · requesting-access-email-sampleEssential Guide: Requesting Access Email Sample for Seamless ...', 'link': 'https://getmage.io/requesting-access-email-sample/', 'snippet': 'Jan 14, 2025 ·   Learn how to write an effective access request email with our sample template. This guide offers tips and examples for requesting access to documents, records, or systems. '}, {'title': 'www.emailsinenglish.com · request-email-for-accessSample Email Requesting Access - Emails In English', 'link': 'https://www.emailsinenglish.com/request-email-for-access-at-office/', 'snippet': 'Aug 10, 2023 ·  From: _________@____.__ (Sender’s email address) Subject: Request for Access. Respected Sir/Madam, My name is _________ (name), and I am writing to bring to your attention a concern regarding access to _________ (mention file name/ portal name/ any other). '}]
# ------------------
# ------------------
# [{'title': 'leadiq.com · 5a1d8a9e2400002400646ee0 · email-formatLeidos Email Formats & Email Address Examples | LeadIQ', 'link': 'https://leadiq.com/c/leidos/5a1d8a9e2400002400646ee0/email-format', 'snippet': " What is Leidos 's email address format? Leidos 's email format typically follows the pattern of First.Last@leidos.com; this email format is used 42% of the time. Other contacts within LeadIQ's database had email formats such as LastF@leidos.com F.Last@leidos.com . "}, {'title': 'www.neverbounce.com · company · leidosLeidos Email verification & Email checker | NeverBounce', 'link': 'https://www.neverbounce.com/company/leidos/357396852', 'snippet': " Leidos Email Format. The most accurate and popular Leidos' email format is first.middle [1 letter].last (ex. John.L.Smith@leidos.com). Leidos also uses first.last (ex. John.Smith@leidos.com) and first [1 letter] + last (ex. JSmith@leidos.com) as email structures. Leidos' uses up to 3 different email patterns. "}, {'title': 'www.signalhire.com · companies · leidosLeidos Email Format | Leidos.com Emails - SignalHire', 'link': 'https://www.signalhire.com/companies/leidos/email-format', 'snippet': ' Here are 6 email formats that are most likely used by the Leidos, where firstNameInitiallastNameInitial (ex. [email protected]) has the highest usage frequency - 66% of the time. Other common formats are firstNameInitial-lastNameInitial and lastNameInitial.firstNameInitial. '}, {'title': 'contactout.com · company · Leidos-email-format-38284Leidos Email Format - ContactOut', 'link': 'https://contactout.com/company/Leidos-email-format-38284', 'snippet': ' The widely used Leidos email format is {first}.{last} (e.g. [email protected]) with 30.54% adoption across the company. '}, {'title': 'aeroleads.com · company · leidos-email-formatLeidos Email Format | leidos.com emails - AeroLeads', 'link': 'https://aeroleads.com/company/leidos-email-format', 'snippet': " The email format used most frequently by leidos's employees is [first].[last] . This email format is being used by 93.33% of leidos employees. "}, {'title': 'www.peoplesmart.com · companies · leidos-incLeidos Inc Employee Directory - Email Address Format, Phone ...', 'link': 'https://www.peoplesmart.com/companies/leidos-inc/7003428', 'snippet': " Leidos Inc's Email Format. We found 8 email formats used by Leidos Inc employees. The most common Leidos Inc email format is last first_initial ex.(doej@leidos.com) being used 45% of the time. "}, {'title': "anymailfinder.com · directory · leidosLeidos's Email Format - leidos.com Email Address - Anymail finder", 'link': 'https://anymailfinder.com/directory/leidos.com', 'snippet': " Whether you're looking to discover the company email format for Leidos, or specific emails for specific Leidos employees, we've got you covered. "}]
# ------------------
# ------------------
# [{'title': 'rocketreach.co · accountemps-email-format_b5c61f41Accountemps Email Format - RocketReach', 'link': 'https://rocketreach.co/accountemps-email-format_b5c61f41f42e0c48', 'snippet': ' The most common Accountemps email format is [first].[last] (ex. jane.doe@roberthalf.com), which is being used by 47.4% of Accountemps work email addresses. Other common Accountemps email patterns are [first] (ex. jane@roberthalf.com) and [last] (ex. doe@roberthalf.com). '}, {'title': 'leadiq.com · 5a1d83b224000024005e4114 · email-formatAccountemps Email Formats & Email Address Examples | LeadIQ', 'link': 'https://leadiq.com/c/accountemps/5a1d83b224000024005e4114/email-format', 'snippet': " What is Accountemps 's email address format? Accountemps 's email format typically follows the pattern of First.Last@accountemps.com; this email format is used 99% of the time. Other contacts within LeadIQ's database had email formats such as FLast@accountemps.com . "}, {'title': 'www.grammarly.com · professional-email-examples10 Professional Email Examples for the Workplace - Grammarly', 'link': 'https://www.grammarly.com/blog/emailing/professional-email-examples/', 'snippet': 'Jan 25, 2024 ·   Get extra guidance on how to word, format, and write emails in the workplace with examples of 10 professional email templates. '}, {'title': 'englishtemplates.com · how-to-write-an-emailHow to Write an Email The Modren Practices', 'link': 'https://englishtemplates.com/how-to-write-an-email/', 'snippet': " Structure the Body of the Email. The body is the core of your email. Use clear and concise language to convey your message. Here's a structure to follow: a. Opening. Briefly introduce yourself if the recipient doesn’t know you and state the purpose of your email. Example: I hope this message finds you well. I am reaching out regarding ... "}, {'title': 'leadiq.com · c · accountempsAccountemps Company Overview, Contact Details & Competitors ...', 'link': 'https://leadiq.com/c/accountemps/5a1d83b224000024005e4114', 'snippet': " Accountemps 's email format typically follows the pattern of . Find more Accountemps email formats with LeadIQ. Accountemps, a division of Robert Half International, is the world's first and largest specialized temporary staffing firm for accounting, finance and bookkeeping professionals. "}, {'title': 'www.indeed.com · format-for-formal-emailHow To Write a Formal Email (Format, Template and Examples)', 'link': 'https://www.indeed.com/career-advice/career-development/format-for-formal-email', 'snippet': "Sep 15, 2023 ·   Simply put, email etiquette is the use of appropriate language, which shows whomever you're speaking to that you care about your relationship with them, value your professional integrity, and that you represent the company in a positive manner. "}, {'title': 'rocketreach.co · accountemps-profile_b5c61f41f42e0c48Accountemps: Contact Details and Business Profile', 'link': 'https://rocketreach.co/accountemps-profile_b5c61f41f42e0c48', 'snippet': " Looking for a particular Accountemps employee's phone or email? Who is the Senior Vice President, Senior Staffing Executive - Salaried Professional Service of Accountemps? How many people are employed at Accountemps? Where is Accountemps based? "}, {'title': 'smartreach.io · blog · formal-email-example23 Professional Emails with Formal Email Examples - SmartReach.io', 'link': 'https://smartreach.io/blog/formal-email-example/', 'snippet': 'Jan 16, 2025 ·   These formal email examples will help you convey your message professionally and clearly. Enhance your email skills and leave a lasting impression with our expert tips. '}]
# ------------------
# Batch 1 completed in 4.19 seconds.
# Waiting for 1 minute before starting the next batch...
#
# Total execution time: 5.20 seconds.

# %%
all_results
# Out:
# [{'query': 'email format for access data consulting corp',
#   'engine': 'Retry',
#   'results': [{'title': 'www.neverbounce.com · company · access-dataAccess Data Consulting Email verification & Email checker ...',
#     'link': 'https://www.neverbounce.com/company/access-data-consulting/693452',
#     'snippet': " The most accurate and popular Access Data Consulting's email format is first [1 letter] + last (ex. JSmith@adcc.com). Access Data Consulting also uses first (ex. John@adcc.com) and first.last (ex. John.Smith@adcc.com) as email structures. "},
#    {'title': 'contactout.com · company · access-data-consultingAccess Data Consulting Corporation Email Format & Employee ...',
#     'link': 'https://contactout.com/company/access-data-consulting-corporation-5997553',
#     'snippet': ' Get details for Access Data Consulting Corporation’s 30 employees, email format for adcc.com and phone numbers. At Access Data Consulting Corporation, we team with clients to help them obtain the absolute best resources for their needs. '},
#    {'title': 'leadiq.com · 5a1d90305400005c0075ce06 · email-formatAccess | Information Management Email Format - leadiq.com',
#     'link': 'https://leadiq.com/c/access--information-management/5a1d90305400005c0075ce06/email-format',
#     'snippet': " Find Access | Information Management's most common email address formats to build your pipeline with confidence. Get accurate & updated contact data with LeadIQ. Book a demo today. "},
#    {'title': 'www.zoominfo.com · c · access-data-consulting-corpAccess Data Consulting - Overview, News & Similar ... - ZoomInfo',
#     'link': 'https://www.zoominfo.com/c/access-data-consulting-corp/693452',
#     'snippet': 'Apr 28, 2020 ·   View Email Formats for Access Data Consulting. Access Data Consulting financials insights. Gather financial insights about Access Data Consulting, including details on funding rounds, investors, total funding, and acquisitions, to gain a comprehensive understanding of their financial strategy. '},
#    {'title': 'www.lusha.com · business · 5f5367910269e7afAccess data consulting corporation - Email Address & Phone ...',
#     'link': 'https://www.lusha.com/business/5f5367910269e7af/',
#     'snippet': ' Reach decision-makers at Access Data Consulting Corporation. Find their phone numbers & email addresses. It’s free. - Lusha '},
#    {'title': 'rocketreach.co · access-data-consultingAccess Data Consulting Corporation Management',
#     'link': 'https://rocketreach.co/access-data-consulting-corporation-management_b5c7029ff42e0d30',
#     'snippet': " Looking for a particular Access Data Consulting Corporation employee's phone or email? "}]},
#  {'query': 'email format for access data consulting corp',
#   'results': [{'title': 'www.neverbounce.com · company · access-dataAccess Data Consulting Email verification & Email checker ...',
#     'link': 'https://www.neverbounce.com/company/access-data-consulting/693452',
#     'snippet': " The most accurate and popular Access Data Consulting's email format is first [1 letter] + last (ex. JSmith@adcc.com). Access Data Consulting also uses first (ex. John@adcc.com) and first.last (ex. John.Smith@adcc.com) as email structures. "},
#    {'title': 'contactout.com · company · access-data-consultingAccess Data Consulting Corporation Email Format & Employee ...',
#     'link': 'https://contactout.com/company/access-data-consulting-corporation-5997553',
#     'snippet': ' Get details for Access Data Consulting Corporation’s 30 employees, email format for adcc.com and phone numbers. At Access Data Consulting Corporation, we team with clients to help them obtain the absolute best resources for their needs. '},
#    {'title': 'leadiq.com · 5a1d90305400005c0075ce06 · email-formatAccess | Information Management Email Format - leadiq.com',
#     'link': 'https://leadiq.com/c/access--information-management/5a1d90305400005c0075ce06/email-format',
#     'snippet': " Find Access | Information Management's most common email address formats to build your pipeline with confidence. Get accurate & updated contact data with LeadIQ. Book a demo today. "},
#    {'title': 'www.zoominfo.com · c · access-data-consulting-corpAccess Data Consulting - Overview, News & Similar ... - ZoomInfo',
#     'link': 'https://www.zoominfo.com/c/access-data-consulting-corp/693452',
#     'snippet': 'Apr 28, 2020 ·   View Email Formats for Access Data Consulting. Access Data Consulting financials insights. Gather financial insights about Access Data Consulting, including details on funding rounds, investors, total funding, and acquisitions, to gain a comprehensive understanding of their financial strategy. '},
#    {'title': 'www.lusha.com · business · 5f5367910269e7afAccess data consulting corporation - Email Address & Phone ...',
#     'link': 'https://www.lusha.com/business/5f5367910269e7af/',
#     'snippet': ' Reach decision-makers at Access Data Consulting Corporation. Find their phone numbers & email addresses. It’s free. - Lusha '},
#    {'title': 'rocketreach.co · access-data-consultingAccess Data Consulting Corporation Management',
#     'link': 'https://rocketreach.co/access-data-consulting-corporation-management_b5c7029ff42e0d30',
#     'snippet': " Looking for a particular Access Data Consulting Corporation employee's phone or email? "}]},
#  {'query': 'email format for access products',
#   'engine': 'Retry',
#   'results': [{'title': 'www.rexandthebeast.com · access-request-email-sampleAccess Request Email Sample: How to Request Access to Files ...',
#     'link': 'https://www.rexandthebeast.com/access-request-email-sample/',
#     'snippet': 'Feb 1, 2025 ·  Access Request Email Template Structure. When requesting access to sensitive information or systems, a well-structured email is essential. Here’s a step-by-step guide to crafting an effective access request email: 1. Subject Line '},
#    {'title': 'getmage.io · sample-email-for-access-requestEffective Guidelines: Crafting A Sample Email For Access ...',
#     'link': 'https://getmage.io/sample-email-for-access-request/',
#     'snippet': 'Jan 10, 2025 ·   Learn how to write an effective sample email for an access request. This article provides guidelines and tips for composing a professional and concise email to obtain access to resources, information, or systems. '},
#    {'title': 'getmage.io · request-access-emailHow to Write an Effective Request Access Email for Smooth ...',
#     'link': 'https://getmage.io/request-access-email/',
#     'snippet': 'Jan 19, 2025 ·   Let’s break down the best way to put your request into an email that’s clear, professional, and likely to get you the access you need. Here’s a simple structure that you can follow: Subject Line: This is your first impression. Keep it clear and concise. Salutation: Always start with a friendly greeting. '},
#    {'title': 'www.matbud.edu.pl · sample-email-for-access-requestSample Email for Access Request: Tips and Examples for ...',
#     'link': 'https://www.matbud.edu.pl/sample-email-for-access-request/',
#     'snippet': 'Apr 21, 2024 ·   To help you out, we’ve put together some sample emails for access requests that you can use as a starting point. These examples cover a range of scenarios, from requesting access to a new software system to asking for permission to view certain documents or files. '},
#    {'title': 'www.rexandthebeast.com · how-to-send-accessHow To Send An Effective Access Request Email - Rexandthebeast',
#     'link': 'https://www.rexandthebeast.com/how-to-send-access-request-email/',
#     'snippet': 'Jan 14, 2025 ·   Learn how to craft an effective access request email to gain permission to confidential information or resources. We provide a step-by-step guide, tips, and examples to help you get the access you need. '},
#    {'title': 'getmage.io · requesting-access-email-sampleEssential Guide: Requesting Access Email Sample for Seamless ...',
#     'link': 'https://getmage.io/requesting-access-email-sample/',
#     'snippet': 'Jan 14, 2025 ·   Learn how to write an effective access request email with our sample template. This guide offers tips and examples for requesting access to documents, records, or systems. '},
#    {'title': 'www.emailsinenglish.com · request-email-for-accessSample Email Requesting Access - Emails In English',
#     'link': 'https://www.emailsinenglish.com/request-email-for-access-at-office/',
#     'snippet': 'Aug 10, 2023 ·  From: _________@____.__ (Sender’s email address) Subject: Request for Access. Respected Sir/Madam, My name is _________ (name), and I am writing to bring to your attention a concern regarding access to _________ (mention file name/ portal name/ any other). '}]},
#  {'query': 'email format for access products',
#   'results': [{'title': 'www.rexandthebeast.com · access-request-email-sampleAccess Request Email Sample: How to Request Access to Files ...',
#     'link': 'https://www.rexandthebeast.com/access-request-email-sample/',
#     'snippet': 'Feb 1, 2025 ·  Access Request Email Template Structure. When requesting access to sensitive information or systems, a well-structured email is essential. Here’s a step-by-step guide to crafting an effective access request email: 1. Subject Line '},
#    {'title': 'getmage.io · sample-email-for-access-requestEffective Guidelines: Crafting A Sample Email For Access ...',
#     'link': 'https://getmage.io/sample-email-for-access-request/',
#     'snippet': 'Jan 10, 2025 ·   Learn how to write an effective sample email for an access request. This article provides guidelines and tips for composing a professional and concise email to obtain access to resources, information, or systems. '},
#    {'title': 'getmage.io · request-access-emailHow to Write an Effective Request Access Email for Smooth ...',
#     'link': 'https://getmage.io/request-access-email/',
#     'snippet': 'Jan 19, 2025 ·   Let’s break down the best way to put your request into an email that’s clear, professional, and likely to get you the access you need. Here’s a simple structure that you can follow: Subject Line: This is your first impression. Keep it clear and concise. Salutation: Always start with a friendly greeting. '},
#    {'title': 'www.matbud.edu.pl · sample-email-for-access-requestSample Email for Access Request: Tips and Examples for ...',
#     'link': 'https://www.matbud.edu.pl/sample-email-for-access-request/',
#     'snippet': 'Apr 21, 2024 ·   To help you out, we’ve put together some sample emails for access requests that you can use as a starting point. These examples cover a range of scenarios, from requesting access to a new software system to asking for permission to view certain documents or files. '},
#    {'title': 'www.rexandthebeast.com · how-to-send-accessHow To Send An Effective Access Request Email - Rexandthebeast',
#     'link': 'https://www.rexandthebeast.com/how-to-send-access-request-email/',
#     'snippet': 'Jan 14, 2025 ·   Learn how to craft an effective access request email to gain permission to confidential information or resources. We provide a step-by-step guide, tips, and examples to help you get the access you need. '},
#    {'title': 'getmage.io · requesting-access-email-sampleEssential Guide: Requesting Access Email Sample for Seamless ...',
#     'link': 'https://getmage.io/requesting-access-email-sample/',
#     'snippet': 'Jan 14, 2025 ·   Learn how to write an effective access request email with our sample template. This guide offers tips and examples for requesting access to documents, records, or systems. '},
#    {'title': 'www.emailsinenglish.com · request-email-for-accessSample Email Requesting Access - Emails In English',
#     'link': 'https://www.emailsinenglish.com/request-email-for-access-at-office/',
#     'snippet': 'Aug 10, 2023 ·  From: _________@____.__ (Sender’s email address) Subject: Request for Access. Respected Sir/Madam, My name is _________ (name), and I am writing to bring to your attention a concern regarding access to _________ (mention file name/ portal name/ any other). '}]},
#  {'query': 'email format for leidos',
#   'engine': 'Retry',
#   'results': [{'title': 'leadiq.com · 5a1d8a9e2400002400646ee0 · email-formatLeidos Email Formats & Email Address Examples | LeadIQ',
#     'link': 'https://leadiq.com/c/leidos/5a1d8a9e2400002400646ee0/email-format',
#     'snippet': " What is Leidos 's email address format? Leidos 's email format typically follows the pattern of First.Last@leidos.com; this email format is used 42% of the time. Other contacts within LeadIQ's database had email formats such as LastF@leidos.com F.Last@leidos.com . "},
#    {'title': 'www.neverbounce.com · company · leidosLeidos Email verification & Email checker | NeverBounce',
#     'link': 'https://www.neverbounce.com/company/leidos/357396852',
#     'snippet': " Leidos Email Format. The most accurate and popular Leidos' email format is first.middle [1 letter].last (ex. John.L.Smith@leidos.com). Leidos also uses first.last (ex. John.Smith@leidos.com) and first [1 letter] + last (ex. JSmith@leidos.com) as email structures. Leidos' uses up to 3 different email patterns. "},
#    {'title': 'www.signalhire.com · companies · leidosLeidos Email Format | Leidos.com Emails - SignalHire',
#     'link': 'https://www.signalhire.com/companies/leidos/email-format',
#     'snippet': ' Here are 6 email formats that are most likely used by the Leidos, where firstNameInitiallastNameInitial (ex. [email protected]) has the highest usage frequency - 66% of the time. Other common formats are firstNameInitial-lastNameInitial and lastNameInitial.firstNameInitial. '},
#    {'title': 'contactout.com · company · Leidos-email-format-38284Leidos Email Format - ContactOut',
#     'link': 'https://contactout.com/company/Leidos-email-format-38284',
#     'snippet': ' The widely used Leidos email format is {first}.{last} (e.g. [email protected]) with 30.54% adoption across the company. '},
#    {'title': 'aeroleads.com · company · leidos-email-formatLeidos Email Format | leidos.com emails - AeroLeads',
#     'link': 'https://aeroleads.com/company/leidos-email-format',
#     'snippet': " The email format used most frequently by leidos's employees is [first].[last] . This email format is being used by 93.33% of leidos employees. "},
#    {'title': 'www.peoplesmart.com · companies · leidos-incLeidos Inc Employee Directory - Email Address Format, Phone ...',
#     'link': 'https://www.peoplesmart.com/companies/leidos-inc/7003428',
#     'snippet': " Leidos Inc's Email Format. We found 8 email formats used by Leidos Inc employees. The most common Leidos Inc email format is last first_initial ex.(doej@leidos.com) being used 45% of the time. "},
#    {'title': "anymailfinder.com · directory · leidosLeidos's Email Format - leidos.com Email Address - Anymail finder",
#     'link': 'https://anymailfinder.com/directory/leidos.com',
#     'snippet': " Whether you're looking to discover the company email format for Leidos, or specific emails for specific Leidos employees, we've got you covered. "}]},
#  {'query': 'email format for leidos',
#   'results': [{'title': 'leadiq.com · 5a1d8a9e2400002400646ee0 · email-formatLeidos Email Formats & Email Address Examples | LeadIQ',
#     'link': 'https://leadiq.com/c/leidos/5a1d8a9e2400002400646ee0/email-format',
#     'snippet': " What is Leidos 's email address format? Leidos 's email format typically follows the pattern of First.Last@leidos.com; this email format is used 42% of the time. Other contacts within LeadIQ's database had email formats such as LastF@leidos.com F.Last@leidos.com . "},
#    {'title': 'www.neverbounce.com · company · leidosLeidos Email verification & Email checker | NeverBounce',
#     'link': 'https://www.neverbounce.com/company/leidos/357396852',
#     'snippet': " Leidos Email Format. The most accurate and popular Leidos' email format is first.middle [1 letter].last (ex. John.L.Smith@leidos.com). Leidos also uses first.last (ex. John.Smith@leidos.com) and first [1 letter] + last (ex. JSmith@leidos.com) as email structures. Leidos' uses up to 3 different email patterns. "},
#    {'title': 'www.signalhire.com · companies · leidosLeidos Email Format | Leidos.com Emails - SignalHire',
#     'link': 'https://www.signalhire.com/companies/leidos/email-format',
#     'snippet': ' Here are 6 email formats that are most likely used by the Leidos, where firstNameInitiallastNameInitial (ex. [email protected]) has the highest usage frequency - 66% of the time. Other common formats are firstNameInitial-lastNameInitial and lastNameInitial.firstNameInitial. '},
#    {'title': 'contactout.com · company · Leidos-email-format-38284Leidos Email Format - ContactOut',
#     'link': 'https://contactout.com/company/Leidos-email-format-38284',
#     'snippet': ' The widely used Leidos email format is {first}.{last} (e.g. [email protected]) with 30.54% adoption across the company. '},
#    {'title': 'aeroleads.com · company · leidos-email-formatLeidos Email Format | leidos.com emails - AeroLeads',
#     'link': 'https://aeroleads.com/company/leidos-email-format',
#     'snippet': " The email format used most frequently by leidos's employees is [first].[last] . This email format is being used by 93.33% of leidos employees. "},
#    {'title': 'www.peoplesmart.com · companies · leidos-incLeidos Inc Employee Directory - Email Address Format, Phone ...',
#     'link': 'https://www.peoplesmart.com/companies/leidos-inc/7003428',
#     'snippet': " Leidos Inc's Email Format. We found 8 email formats used by Leidos Inc employees. The most common Leidos Inc email format is last first_initial ex.(doej@leidos.com) being used 45% of the time. "},
#    {'title': "anymailfinder.com · directory · leidosLeidos's Email Format - leidos.com Email Address - Anymail finder",
#     'link': 'https://anymailfinder.com/directory/leidos.com',
#     'snippet': " Whether you're looking to discover the company email format for Leidos, or specific emails for specific Leidos employees, we've got you covered. "}]},
#  {'query': 'email format for accountemps',
#   'engine': 'Retry',
#   'results': [{'title': 'rocketreach.co · accountemps-email-format_b5c61f41Accountemps Email Format - RocketReach',
#     'link': 'https://rocketreach.co/accountemps-email-format_b5c61f41f42e0c48',
#     'snippet': ' The most common Accountemps email format is [first].[last] (ex. jane.doe@roberthalf.com), which is being used by 47.4% of Accountemps work email addresses. Other common Accountemps email patterns are [first] (ex. jane@roberthalf.com) and [last] (ex. doe@roberthalf.com). '},
#    {'title': 'leadiq.com · 5a1d83b224000024005e4114 · email-formatAccountemps Email Formats & Email Address Examples | LeadIQ',
#     'link': 'https://leadiq.com/c/accountemps/5a1d83b224000024005e4114/email-format',
#     'snippet': " What is Accountemps 's email address format? Accountemps 's email format typically follows the pattern of First.Last@accountemps.com; this email format is used 99% of the time. Other contacts within LeadIQ's database had email formats such as FLast@accountemps.com . "},
#    {'title': 'www.grammarly.com · professional-email-examples10 Professional Email Examples for the Workplace - Grammarly',
#     'link': 'https://www.grammarly.com/blog/emailing/professional-email-examples/',
#     'snippet': 'Jan 25, 2024 ·   Get extra guidance on how to word, format, and write emails in the workplace with examples of 10 professional email templates. '},
#    {'title': 'englishtemplates.com · how-to-write-an-emailHow to Write an Email The Modren Practices',
#     'link': 'https://englishtemplates.com/how-to-write-an-email/',
#     'snippet': " Structure the Body of the Email. The body is the core of your email. Use clear and concise language to convey your message. Here's a structure to follow: a. Opening. Briefly introduce yourself if the recipient doesn’t know you and state the purpose of your email. Example: I hope this message finds you well. I am reaching out regarding ... "},
#    {'title': 'leadiq.com · c · accountempsAccountemps Company Overview, Contact Details & Competitors ...',
#     'link': 'https://leadiq.com/c/accountemps/5a1d83b224000024005e4114',
#     'snippet': " Accountemps 's email format typically follows the pattern of . Find more Accountemps email formats with LeadIQ. Accountemps, a division of Robert Half International, is the world's first and largest specialized temporary staffing firm for accounting, finance and bookkeeping professionals. "},
#    {'title': 'www.indeed.com · format-for-formal-emailHow To Write a Formal Email (Format, Template and Examples)',
#     'link': 'https://www.indeed.com/career-advice/career-development/format-for-formal-email',
#     'snippet': "Sep 15, 2023 ·   Simply put, email etiquette is the use of appropriate language, which shows whomever you're speaking to that you care about your relationship with them, value your professional integrity, and that you represent the company in a positive manner. "},
#    {'title': 'rocketreach.co · accountemps-profile_b5c61f41f42e0c48Accountemps: Contact Details and Business Profile',
#     'link': 'https://rocketreach.co/accountemps-profile_b5c61f41f42e0c48',
#     'snippet': " Looking for a particular Accountemps employee's phone or email? Who is the Senior Vice President, Senior Staffing Executive - Salaried Professional Service of Accountemps? How many people are employed at Accountemps? Where is Accountemps based? "},
#    {'title': 'smartreach.io · blog · formal-email-example23 Professional Emails with Formal Email Examples - SmartReach.io',
#     'link': 'https://smartreach.io/blog/formal-email-example/',
#     'snippet': 'Jan 16, 2025 ·   These formal email examples will help you convey your message professionally and clearly. Enhance your email skills and leave a lasting impression with our expert tips. '}]},
#  {'query': 'email format for accountemps',
#   'results': [{'title': 'rocketreach.co · accountemps-email-format_b5c61f41Accountemps Email Format - RocketReach',
#     'link': 'https://rocketreach.co/accountemps-email-format_b5c61f41f42e0c48',
#     'snippet': ' The most common Accountemps email format is [first].[last] (ex. jane.doe@roberthalf.com), which is being used by 47.4% of Accountemps work email addresses. Other common Accountemps email patterns are [first] (ex. jane@roberthalf.com) and [last] (ex. doe@roberthalf.com). '},
#    {'title': 'leadiq.com · 5a1d83b224000024005e4114 · email-formatAccountemps Email Formats & Email Address Examples | LeadIQ',
#     'link': 'https://leadiq.com/c/accountemps/5a1d83b224000024005e4114/email-format',
#     'snippet': " What is Accountemps 's email address format? Accountemps 's email format typically follows the pattern of First.Last@accountemps.com; this email format is used 99% of the time. Other contacts within LeadIQ's database had email formats such as FLast@accountemps.com . "},
#    {'title': 'www.grammarly.com · professional-email-examples10 Professional Email Examples for the Workplace - Grammarly',
#     'link': 'https://www.grammarly.com/blog/emailing/professional-email-examples/',
#     'snippet': 'Jan 25, 2024 ·   Get extra guidance on how to word, format, and write emails in the workplace with examples of 10 professional email templates. '},
#    {'title': 'englishtemplates.com · how-to-write-an-emailHow to Write an Email The Modren Practices',
#     'link': 'https://englishtemplates.com/how-to-write-an-email/',
#     'snippet': " Structure the Body of the Email. The body is the core of your email. Use clear and concise language to convey your message. Here's a structure to follow: a. Opening. Briefly introduce yourself if the recipient doesn’t know you and state the purpose of your email. Example: I hope this message finds you well. I am reaching out regarding ... "},
#    {'title': 'leadiq.com · c · accountempsAccountemps Company Overview, Contact Details & Competitors ...',
#     'link': 'https://leadiq.com/c/accountemps/5a1d83b224000024005e4114',
#     'snippet': " Accountemps 's email format typically follows the pattern of . Find more Accountemps email formats with LeadIQ. Accountemps, a division of Robert Half International, is the world's first and largest specialized temporary staffing firm for accounting, finance and bookkeeping professionals. "},
#    {'title': 'www.indeed.com · format-for-formal-emailHow To Write a Formal Email (Format, Template and Examples)',
#     'link': 'https://www.indeed.com/career-advice/career-development/format-for-formal-email',
#     'snippet': "Sep 15, 2023 ·   Simply put, email etiquette is the use of appropriate language, which shows whomever you're speaking to that you care about your relationship with them, value your professional integrity, and that you represent the company in a positive manner. "},
#    {'title': 'rocketreach.co · accountemps-profile_b5c61f41f42e0c48Accountemps: Contact Details and Business Profile',
#     'link': 'https://rocketreach.co/accountemps-profile_b5c61f41f42e0c48',
#     'snippet': " Looking for a particular Accountemps employee's phone or email? Who is the Senior Vice President, Senior Staffing Executive - Salaried Professional Service of Accountemps? How many people are employed at Accountemps? Where is Accountemps based? "},
#    {'title': 'smartreach.io · blog · formal-email-example23 Professional Emails with Formal Email Examples - SmartReach.io',
#     'link': 'https://smartreach.io/blog/formal-email-example/',
#     'snippet': 'Jan 16, 2025 ·   These formal email examples will help you convey your message professionally and clearly. Enhance your email skills and leave a lasting impression with our expert tips. '}]}]

# %%
 search_engines = [fetch_yahoo_results, fetch_bing_results]  # Alternating search engines
engine_pt = 0
for batch_idx in range(num_batches):
    print (batch_idx, ":", num_batches)
    # Start time for this batch
    batch_start_time = time.time()
    # Get queries for the current batch
    start_idx = batch_idx * batch_size
    end_idx = start_idx + batch_size
    current_queries = queries[start_idx:end_idx]
    print ("-------->", start_idx,"::",end_idx)
    engine_pt = 1- engine_pt
    print ("engine_pt:", engine_pt)
    for query in current_queries:
        try:
            # Try fetching results with retries
            results = fetch_results_with_retry(query, num_results=5)
            # Ensure that we always have at least one result entry for each engine
            if not results:  # If results are empty, append a result with "NA"
                results.append({'title': 'NA', 'link': 'NA', 'snippet': 'NA'})
            all_results.append({'query': query, 'engine': "Retry", 'results': results})
        except Exception as e:
            print(f"Failed to fetch results for query '{query}': {e}")
# Out:
# 0 : 4
# --------> 0 :: 4
# engine_pt: 1
# 1 : 4
# --------> 4 :: 8
# engine_pt: 0
# 2 : 4
# --------> 8 :: 12
# engine_pt: 1
# 3 : 4
# --------> 12 :: 16
# engine_pt: 0

# %%
import time
from datetime import datetime, timedelta

# %%
d= datetime.now()
d
# Out:
# datetime.datetime(2025, 2, 11, 0, 13, 34, 841890)

# %%
yahoo_down_duration = timedelta(hours=1)  # Yahoo stays down for 1 hour

datetime.now() >= d + yahoo_down_duration
# Out:
# False
